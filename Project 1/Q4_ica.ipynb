# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import FastICA
from sklearn.preprocessing import Imputer

# %%
df = pd.read_csv("C:/Users/DELL/Desktop/DM/dist1_500_1.txt",header= None,sep = " ")
df1 = pd.read_csv("C:/Users/DELL/Desktop/DM/dist1_500_2.txt",header= None,sep = " ")
df2 = pd.read_csv("C:/Users/DELL/Desktop/DM/dist2_500_1.txt",header= None,sep = " ")
df3 = pd.read_csv("C:/Users/DELL/Desktop/DM/dist2_500_2.txt",header= None,sep = " ")
dataset1=df.append(df1)
dataset2=df1.append(df2)
clean_1=dataset1.dropna(axis='index')
clean_2=dataset2.dropna(axis='index')
X=clean_1
X.shape
Y=clean_2

# %%
sc = StandardScaler()

# %%
data1_std = sc.fit_transform(X)
data2_std = sc.fit_transform(Y)

# %%
ica = FastICA(n_components = 2)

# %%
data1_std_ica = ica.fit_transform(data1_std)
data2_std_ica = ica.fit_transform(data2_std)

# %%
data1_std_ica
# Out:
# array([[-0.00715602, -0.02007224],
#        [ 0.01271471, -0.0322172 ],
#        [-0.00710587,  0.04250358],
#        ...,
#        [ 0.00542185,  0.04627162],
#        [ 0.01263601, -0.01783659],
#        [-0.05026842, -0.03122481]])

# %%
data2_std_ica
# Out:
# array([[-0.0192035 ,  0.01475446],
#        [ 0.00658661,  0.03058993],
#        [ 0.01128514,  0.01713634],
#        ...,
#        [ 0.01511849, -0.02080515],
#        [-0.00522682, -0.0101765 ],
#        [ 0.0115164 , -0.01648232]])

# %%
plt.scatter(data1_std_ica[:,0], data1_std_ica[:,1])

# %%
plt.scatter(data2_std_ica[:,0], data2_std_ica[:,1])

# %%
plt.plot(data1_std_ica)
# Out:
# [<matplotlib.lines.Line2D at 0x7773fe97f0>,
#  <matplotlib.lines.Line2D at 0x7773fe9940>]

# %%
plt.plot(data2_std_ica)
# Out:
# [<matplotlib.lines.Line2D at 0x777404f208>,
#  <matplotlib.lines.Line2D at 0x777404f358>]
